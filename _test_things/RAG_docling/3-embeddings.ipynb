# %%
import os

from docling.chunking import HybridChunker
from docling.document_converter import DocumentConverter
from dotenv import load_dotenv
from openai import OpenAI
from utils.tokenizer import OpenAITokenizerWrapper

env_path = os.path.join(os.sep, "Users", "leon", ".env")
load_dotenv(env_path)

# Initialize OpenAI client (make sure you have OPENAI_API_KEY in your environment variables)
client = OpenAI()


tokenizer = OpenAITokenizerWrapper()  # Load our custom tokenizer for OpenAI
MAX_TOKENS = 256  # text-embedding-3-large's maximum context length


# --------------------------------------------------------------
# Extract the data
# --------------------------------------------------------------


converter = DocumentConverter()
result = converter.convert("test.md")


# --------------------------------------------------------------
# Apply hybrid chunking
# --------------------------------------------------------------


chunker = HybridChunker(
    tokenizer=tokenizer,
    max_tokens=MAX_TOKENS,
    merge_peers=False
)


chunk_iter = chunker.chunk(dl_doc=result.document)

# %%
import lancedb
from lancedb.embeddings import get_registry
from lancedb.pydantic import LanceModel, Vector

LANCEDB_DIR = "../data/lancedb"
TABLE_NAME = "climatepolicyradar"

# --------------------------------------------------------------
# Create a LanceDB database and table
# --------------------------------------------------------------

# Create a LanceDB database
db = lancedb.connect(LANCEDB_DIR)


# Get the OpenAI embedding function
func = get_registry().get("openai").create(name="text-embedding-3-small")


# Define a simplified metadata schema
class ChunkMetadata(LanceModel):
    """
    You must order the fields in alphabetical order.
    This is a requirement of the Pydantic implementation.
    """

    filename: str | None
    title: str | None


# Define the main Schema
class Chunks(LanceModel):
    text: str = func.SourceField()
    vector: Vector(func.ndims()) = func.VectorField()  # type: ignore | Pass the embeddings-function to the database
    metadata: ChunkMetadata


table = db.create_table(TABLE_NAME, schema=Chunks, mode="overwrite")

# --------------------------------------------------------------
# Prepare the chunks for the table
# --------------------------------------------------------------

# Create table with processed chunks
processed_chunks = [
    {
        "text": chunk.text,
        "metadata": {
            "filename": chunk.meta.origin.filename,
            "title": chunk.meta.headings[0] if chunk.meta.headings else None,
        },
    }
    for chunk in chunk_iter
]

# --------------------------------------------------------------
# Add the chunks to the table (automatically embeds the text)
# --------------------------------------------------------------

table.add(processed_chunks)

# %%
# --------------------------------------------------------------
# Load the table
# --------------------------------------------------------------

df = table.to_pandas()

print(len(df))

df
# Out:
# 58
#                                                  text  \
# 0   EUROPEAN COMMISSION Brussels, 18.5.2022 COM(20...
# 1   9 bcm of natural gas annually by 2027. Solar e...
# 2   Solar energy, combined with energy efficiency,...
# 3               EU large-scale skills partnership for
# 4   onshore renewable energy under the Pact for Sk...
# 5   18 GW that year. It delivered around 5% of tot...
# 6   They can be deployed very rapidly, as they uti...
# 7   by 2026; oall existing public and commercial b...
# 8   000 by 2025. -Ensure that energy poor and vuln...
# 9   buildings for quick interventions (Energy Perf...
# 10  of electricity after the first year of its imp...
# 11  ensuring a coordinated support framework for s...
# 12  increase visibility for project developers and...
# 13  implementation of the Commission Recommendatio...
# 14  purposes different than solar energy productio...
# 15  (or agri-PV). The two activities can establish...
# 16  designing their National Strategic Plans for t...
# 17  sound barriers in a pilot project in the Nethe...
# 18  for 10%. There is already a lack of skilled wo...
# 19  the Member States of the Council Recommendatio...
# 20  workforce reskilling and upskilling and labour...
# 21  guidelines include exemptions from mandatory c...
# 22  including those below or equal to 1 MW of inst...
# 23  In addition, the 2021 proposal for the revisio...
# 24  for the energy poor and vulnerable. This issue...
# 25  in the most remote regions, i.e. the EU outerm...
# 26  the current EU legislation, national regulator...
# 27  impact on grid costs. Time-differentiated dist...
# 28  addition, Member States are encouraged to make...
# 29  The July 2021 proposal for a revision of the R...
# 30  to overall grid resilience. The opportunities ...
# 31  into the energy system if they can effectively...
# 32  industry The contribution of solar to decarbon...
# 33  and on new residential buildings in a gradual ...
# 34  be acquired through a PPA. In addition, provis...
# 35  guidance to local authorities on how to deal w...
# 36  5 GW of solar PV projects had directly signed ...
# 37  abundant, but the energy infrastructure bringi...
# 38  the Recovery and Resilience Fund which already...
# 39  2023. 3.Ensuring access to sustainable solar e...
# 40  in case of global or country-specific events. ...
# 41  added. In addition, the EU will step in to ens...
# 42  solar energy research and innovation, focused ...
# 43  areas identified through the local smart speci...
# 44  However, it is important to continue to reduce...
# 45  Since private actors play a central role in th...
# 46  Suppliers from within the EU currently cover a...
# 47  Strengthening the sustainable and responsible ...
# 48  Figure: Breakdown of Gross Value Added through...
# 49  of extensive external supply disruptions. This...
# 50  PV sector, including the emerging circularity ...
# 51  support relevant projects boosting local devel...
# 52  gaps on the supply side. In the context of rap...
# 53  volatility and geopolitical risks. Beyond Euro...
# 54  UN Sustainable Development Goal for 2030. Sola...
# 55  Africa’s efforts to adopt innovative technolog...
# 56  the EU is also exploring opportunities to enga...
# 57  use of this simple and abundant resource to po...
#
#                                                vector  \
# 0   [-0.004901573, 0.015297584, 0.029615412, 0.011...
# 1   [-0.04308129, 0.018255888, 0.06313675, 0.01090...
# 2   [-0.022207702, 0.015508301, 0.05563516, 0.0382...
# 3   [-0.0014660229, 0.033820212, 0.05075594, 8.296...
# 4   [-0.03702904, 0.029328406, 0.03522489, 0.00318...
# 5   [-0.044564977, 0.012687859, 0.07369756, 0.0048...
# 6   [-0.026288439, 0.01813808, 0.07533193, 0.01630...
# 7   [1.1175928e-06, 0.029705035, 0.07075471, 0.014...
# 8   [-0.0029145256, 0.0012499227, 0.070254475, 0.0...
# 9   [-0.013426594, 0.03918594, 0.07120783, 0.02743...
# 10  [-0.02272226, 0.007346864, 0.046236884, 0.0009...
# 11  [-0.03178312, -0.027736273, 0.08382413, 0.0067...
# 12  [-0.02150433, -0.032460246, 0.08732132, 0.0304...
# 55  [-0.03264551, -0.029173037, 0.06627703, 0.0371...
# 56  [-0.03246962, 0.008447471, 0.06619237, 0.00977...
# 57  [-0.019011127, 0.034136124, 0.05444999, 0.0016...
#
#                                   metadata
# 0   {'filename': 'test.md', 'title': None}
# 1   {'filename': 'test.md', 'title': None}
# 2   {'filename': 'test.md', 'title': None}
# 3   {'filename': 'test.md', 'title': None}
# 4   {'filename': 'test.md', 'title': None}
# 5   {'filename': 'test.md', 'title': None}
# 6   {'filename': 'test.md', 'title': None}
# 7   {'filename': 'test.md', 'title': None}
# 8   {'filename': 'test.md', 'title': None}
# 9   {'filename': 'test.md', 'title': None}
# 10  {'filename': 'test.md', 'title': None}
# 11  {'filename': 'test.md', 'title': None}
# 12  {'filename': 'test.md', 'title': None}
# 13  {'filename': 'test.md', 'title': None}
# 14  {'filename': 'test.md', 'title': None}
# 15  {'filename': 'test.md', 'title': None}
# 16  {'filename': 'test.md', 'title': None}
# 17  {'filename': 'test.md', 'title': None}
# 18  {'filename': 'test.md', 'title': None}
# 19  {'filename': 'test.md', 'title': None}
# 20  {'filename': 'test.md', 'title': None}
# 21  {'filename': 'test.md', 'title': None}
# 22  {'filename': 'test.md', 'title': None}
# 23  {'filename': 'test.md', 'title': None}
# 24  {'filename': 'test.md', 'title': None}
# 25  {'filename': 'test.md', 'title': None}
# 26  {'filename': 'test.md', 'title': None}
# 27  {'filename': 'test.md', 'title': None}
# 28  {'filename': 'test.md', 'title': None}
# 29  {'filename': 'test.md', 'title': None}
# 30  {'filename': 'test.md', 'title': None}
# 31  {'filename': 'test.md', 'title': None}
# 32  {'filename': 'test.md', 'title': None}
# 33  {'filename': 'test.md', 'title': None}
# 34  {'filename': 'test.md', 'title': None}
# 35  {'filename': 'test.md', 'title': None}
# 36  {'filename': 'test.md', 'title': None}
# 37  {'filename': 'test.md', 'title': None}
# 38  {'filename': 'test.md', 'title': None}
# 39  {'filename': 'test.md', 'title': None}
# 40  {'filename': 'test.md', 'title': None}
# 41  {'filename': 'test.md', 'title': None}
# 42  {'filename': 'test.md', 'title': None}
# 43  {'filename': 'test.md', 'title': None}
# 44  {'filename': 'test.md', 'title': None}
# 45  {'filename': 'test.md', 'title': None}
# 46  {'filename': 'test.md', 'title': None}
# 47  {'filename': 'test.md', 'title': None}
# 48  {'filename': 'test.md', 'title': None}
# 49  {'filename': 'test.md', 'title': None}
# 50  {'filename': 'test.md', 'title': None}
# 51  {'filename': 'test.md', 'title': None}
# 52  {'filename': 'test.md', 'title': None}
# 53  {'filename': 'test.md', 'title': None}
# 54  {'filename': 'test.md', 'title': None}
# 55  {'filename': 'test.md', 'title': None}
# 56  {'filename': 'test.md', 'title': None}
# 57  {'filename': 'test.md', 'title': None}
